# %% [markdown]
# <a href="https://colab.research.google.com/github/waghvaishnav/Model-Evaluation-Fine-Tuning-in-the-Machine-Learning-Toolkit/blob/main/HyperparameteTuning_RandomizedSearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from sklearn.datasets import load_iris
data = load_iris()
x = data.data
y = data.target

#providing the multiple eatimators to the gridsearchcv :
grid_param = {"decision_tree":{"model":DecisionTreeClassifier(),"param":{"max_depth":[10,12,15,2],"criterion":["gini","entropy"]}},
              "svc":{"model":SVC(gamma="auto"),"param":{"kernel":["linear","rbf"],"C":[1,10,15]}}
  }
dict1 = []
for key,val in grid_param.items():
  scores = RandomizedSearchCV(val["model"],val["param"],cv=5,return_train_score=False,n_iter=20)
  scores.fit(x,y)
  dict1.append({"model":key,
                "best_score":scores.best_score_,
                "best_param":scores.best_params_
  }

  )
dict1
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 8 is smaller than n_iter=20. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 6 is smaller than n_iter=20. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [{'model': 'decision_tree',
#   'best_score': np.float64(0.9666666666666668),
#   'best_param': {'max_depth': 12, 'criterion': 'gini'}},
#  {'model': 'svc',
#   'best_score': np.float64(0.9800000000000001),
#   'best_param': {'kernel': 'linear', 'C': 1}}]

# %%
scores.best_score_
# Out:
# np.float64(0.9800000000000001)

# %%
import pandas as pd

df = pd.DataFrame(scores.cv_results_)

df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.005269      0.002714         0.003755        0.001629       linear
# 1       0.004599      0.001259         0.003534        0.002040          rbf
# 2       0.002754      0.001016         0.004315        0.004583       linear
# 3       0.012260      0.000403         0.007518        0.005026          rbf
# 4       0.011987      0.000303         0.007393        0.004953       linear
# 5       0.011242      0.003203         0.009056        0.003885          rbf
#
#    param_C                         params  split0_test_score  \
# 0        1   {'kernel': 'linear', 'C': 1}           0.966667
# 1        1      {'kernel': 'rbf', 'C': 1}           0.966667
# 2       10  {'kernel': 'linear', 'C': 10}           1.000000
# 3       10     {'kernel': 'rbf', 'C': 10}           0.966667
# 4       15  {'kernel': 'linear', 'C': 15}           1.000000
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

model = DecisionTreeClassifier()

para = {"max_depth":[5,10,15],
        "criterion":["gini","entropy"]}

searchcv = RandomizedSearchCV(model,para,cv=5,n_iter=3)

searchcv.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_iter=3,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [5, 10, 15]})

# %%
searchcv.best_score_
# Out:
# np.float64(0.9533333333333334)
